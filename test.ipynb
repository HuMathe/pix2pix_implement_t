# %%
from header import *
import cv2
import matplotlib.pyplot as plt

# %%
a = np.load('lossD.npy')
b = np.load('lossG.npy')
plt.plot(np.arange(len(a)), a)
plt.plot(np.arange(len(b)), b*5, color = 'pink')
plt.show()
