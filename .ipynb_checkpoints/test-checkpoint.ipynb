# %%
from header import *
import cv2
import matplotlib.pyplot as plt

# %%
a = np.load('lossD.npy')
b = np.load('lossG.npy')
plt.plot(np.arange(len(a)), a*70)
plt.plot(np.arange(len(b)), b, color = 'pink')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4a61efd00da6> in <module>
# ----> 1 a = np.load('errorD.npy')
#       2 b = np.load('errorG.npy')
#       3 plt.plot(np.arange(len(a)), a*70)
#       4 plt.plot(np.arange(len(b)), b, color = 'pink')
#       5 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: 'errorD.npy'

# %%
a = np.load("avg_psnr.npy")
b = np.load("max_psnr.npy")
plt.plot(np.arange(len(a)), a)
plt.plot(np.arange(len(b)), b)
plt.show()
